# %%
import requests
from requests import get

# %%
import requests
web = requests.get('https://water.taiwanstat.com/')  # 使用 get 方法
print(web.text)    # 讀取並印出 text 屬性
# Out:
# <!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" lang="zh-TW"><head><meta property="og:title" content="台灣水庫即時水情"><meta http-equiv="Content-Type" content="text/html; charset=utf-8"><meta property="og:site_name" content="台灣水庫即時水情"><meta property="og:description" content="台灣水庫即時水情-視覺化, 即時蓄水量、水位變化..."><meta property="og:image" content="http://i.imgur.com/04AFcnA.png"><meta property="og:image:type" content="image/png"><meta name="author" content="Chi-Hsuan Huang"><meta name="citation_authors" content="Po-An Yang"><meta name="description" content="台灣水庫即時水情-視覺化, 即時蓄水量、水位變化"><title>台灣水庫即時水情</title><meta property="og:locale" content="zh_TW"><meta name="viewport" content="width=device-width,initial-scale=1"><link rel="icon" type="image/png" href="//static.taiwanstat.com/favicon.ico"><link rel="shortcut icon" href="//static.taiwanstat.com/favicon.ico" type="image/x-icon"><link rel="stylesheet" href="//static.taiwanstat.com/css/style.min.css"><link rel="stylesheet" href="//storage.googl
# ...

# %%
import requests
web = requests.get('https://data.kcg.gov.tw/dataset/6f29f6f4-2549-4473-aa90-bf60d10895dc/resource/30dfc2cf-17b5-4a40-8bb7-c511ea166bd3/download/lightrailtraffic.json')
print(web.json())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\python3108\lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\python3108\lib\json\__init__.py:335, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     334     if s.startswith('\ufeff'):
# --> 335         raise JSONDecodeError("Unexpected UTF-8 BOM (decode using utf-8-sig)",
#     336                               s, 0)
#     337 else:
#
# JSONDecodeError: Unexpected UTF-8 BOM (decode using utf-8-sig): line 1 column 1 (char 0)
#
# ...

# %%
import requests
web = requests.get('https://data.kcg.gov.tw/')
if web.status_code == 404:
  print('找不到網頁')
else:
    print(web)
# Out:
# <Response [200]>

# %%
import requests
# 設定參數
params = {
    'name':'oxxo',
    'age':'18'
}
# 加入參數
web = requests.get('https://script.google.com/macros/s/AKfycbw5PnzwybI_VoZaHz65TpA5DYuLkxIF-HUGjJ6jRTOje0E6bVo/exec', params=params)
print(web.text)
# Out:
# 你的名字是：oxxo，年紀：18 歲。

# %%
import requests
#import password
apikey="2c345b7a-6a24-4fd2-8e56-6e3ad28d56e4"
url=f"https://data.moenv.gov.tw/api/v2/fac_p_07?api_key={apikey}"
print(url)
r=requests.get(url)
print(r.text)
# Out:
# https://data.moenv.gov.tw/api/v2/fac_p_07?api_key=2c345b7a-6a24-4fd2-8e56-6e3ad28d56e4
# {
#     "fields": [
#         {
#             "id": "country",
#             "type": "text",
#             "info": {
#                 "label": "縣市名稱"
#             }
#         },
#         {
#             "id": "city",
#             "type": "text",
#             "info": {
#                 "label": "鄉鎮市名稱"
#             }
#         },
#         {
#             "id": "village",
#             "type": "text",
#             "info": {
#                 "label": "村里名稱"
#             }
#         },
#         {
#             "id": "number",
#             "type": "text",
#             "info": {
#                 "label": "建檔編號"
#             }
#         },
#         {
#             "id": "name",
#             "type": "text",
#             "info": {
#                 "label": "建檔名稱"
#             }
#         },
#         {
#             "id": "address",
#             "type": "text",
# ...
